# %%
# TrueSight Demo - First Test Notebook
# Trying to load and show a test image. No real model yet.

from PIL import Image
import matplotlib.pyplot as plt

# Load a local image (make sure demo.jpg is in the same folder)
img = Image.open('demo.jpg')
plt.imshow(img)
plt.axis('off')
plt.title("Test Image")
plt.show()

print("Prediction: Not implemented yet, just a placeholder")
# Out:
# Prediction: Not implemented yet, just a placeholder
